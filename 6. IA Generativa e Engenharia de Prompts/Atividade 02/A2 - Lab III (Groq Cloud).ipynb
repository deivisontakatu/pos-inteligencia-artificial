# %%
# !pip -q install groq
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 3.8 MB/s eta 0:00:00

# %%
import os
from getpass import getpass
from groq import Groq

# %%
os.environ["GROQ_API_KEY"] = getpass("Chave da Groq: ")
# Out:
# Chave da Groq: ··········

# %%
client = Groq(
    api_key=os.environ["GROQ_API_KEY"]
)

prompt = input("Digite sua pergunta: ")

resposta = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[
        {
            "role": "system",
            "content": "Você é um assistente didático e objetivo."
        },
        {
            "role": "user",
            "content": prompt
        }
    ],
    temperature=0.5,
    max_tokens=300
)

print("\nResposta do modelo:\n")
print(resposta.choices[0].message.content)
# Out:
# Digite sua pergunta: Quem venceu a copa do mundo em 1998?
#
# Resposta do modelo:
#
# A França venceu a Copa do Mundo de 1998, sediada na França. Eles derrotaram a Croácia na final por 3 a 0, com gols de Zinedine Zidane (em uma penalidade), Emmanuel Petit e Lilian Thuram. Essa foi a primeira vez que a França conquistou a Copa do Mundo.
